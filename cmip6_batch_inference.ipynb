# %%
import numpy as np
import xarray as xr
import toml
import munch
from tqdm import tqdm
import torch
import datetime

import warnings
warnings.filterwarnings("ignore")

from Fires._utilities.utils_mlflow import load_model_from_mlflow
from batch_prediction import get_prediction_for_data

# %%
run_name=input()
_ = load_model_from_mlflow(run_name, provenance=True)
# Out:
#  last

# %%
# Do the inference
prediction = get_prediction_for_data(dataset_path=dataset_path,
                          model_path=f"MLFLOW/{run_name}/last_model/data/model.pth",
                                    verbose=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 3
#       1 # Do the inference
#       2 dataset = None
# ----> 3 prediction = get_prediction_for_data(dataset=dataset,
#       4                           model_path=f"MLFLOW/{run_name}/last_model/data/model.pth",
#       5                                     verbose=False)
#
# File /jupyter-workspace/persistent-storage/ML4Fires/batch_prediction.py:16, in get_prediction_for_data(dataset, model_path, verbose)
#      14 if verbose:
#      15     print(model)
# ---> 16 return do_inference(dataset=dataset,
#      17                     model=model)
#
# File /jupyter-workspace/persistent-storage/ML4Fires/Fires/_utilities/utils_inference.py:450, in do_inference(dataset, model)
#     448 prediction_cpu = []
#     449 with torch.no_grad():
# --> 450     for idx in range(dataset.shape[0]):
#     451         prediction = model(dataset[idx].unsqueeze(0).to('cuda:0'))
#     452         prediction_cpu.append(prediction.cpu().detach().numpy())
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
import ipywidgets as widgets

monthly_agg = widgets.Dropdown(
    options=[('Mean', 'mean'), ('Sum', 'sum'), ('Median', 'median'),
             ('Mode', 'mode')],
    value = 'sum',
    style={'description_width': '150px'}, 
    description='Monthly aggregate', disabled=False,)

monthly_add_period = widgets.Dropdown(
    options=[('1 Month', '1M'), ('2 Months', '2M'), ('4 Months', '4M'),
             ('6 Month', '6M')],
    value = '1M',
    style={'description_width': '150px'}, 
    description='Monthly aggregate period', disabled=False,)

yearly_agg = widgets.Dropdown(
    options=[('Mean', 'mean'), ('Sum', 'sum'), ('Median', 'median'),
             ('Mode', 'mode')],
    value = 'mean',
    style={'description_width': '150px'}, 
    description='Yearly aggregate', disabled=False,)

decadal_agg = widgets.Dropdown(
    options=[('Mean', 'mean'), ('Sum', 'sum'), ('Median', 'median'),
             ('Mode', 'mode')],
    value = 'mean',
    style={'description_width': '150px'}, 
    description='Decadal aggregate', disabled=False,)

display(widgets.HBox([monthly_agg,
                      monthly_add_period]))
        
display(widgets.VBox([yearly_agg,
                      decadal_agg]))
# Out:
# HBox(children=(Dropdown(description='Monthly aggregate', index=1, options=(('Mean', 'mean'), ('Sum', 'sum'), (…
# VBox(children=(Dropdown(description='Yearly aggregate', options=(('Mean', 'mean'), ('Sum', 'sum'), ('Median', …

# %%
temporal_aggregate_scheme = {"monthly":[monthly_agg.value,monthly_add_period.value],
                             "yearly":yearly_agg.value,
                            "decadal":decadal_agg.value}
